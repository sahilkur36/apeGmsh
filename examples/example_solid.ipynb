# %%
from pyGmsh import pyGmsh
from pyGmsh import Numberer, FEMData
import numpy as np
import openseespy.opensees as ops
from pathlib import Path

# %%
model_iges_path = Path(r'C:\Users\nmora\Github\pyGmsh\acad') / 'solid.iges'
assert model_iges_path.exists(), model_iges_path

m1 = pyGmsh(
    model_name='solid',
    verbose=True
)
m1.initialize()

m1.model.load_iges(
    file_path=model_iges_path,
    highest_dim_only=True
)

#m1.physical.add_curve(tags=[6, 7], name="UxUy")
#m1.physical.add_curve(tags=[2, 4], name="load")

m1.model.viewer()

(m1.mesh
     .set_global_size(0.5)
     .generate(dim=3)
)

m1.mesh.viewer()

m1.mesh.renumber_mesh(method='rcm')

fem_data = m1.mesh.get_fem_data()
# Out:
# Gmsh version: 4.15.1
# [Model] loaded IGES ← solid.iges  {3: 1}
# [picker] LMB drag → box-select (936,509)→(957,566) crossing=True
# [picker] box raw=(936,509)-(957,566) scaled=(936,509)-(957,566) ratio=(1.00,1.00)
#   centroid (0, 1): display=(530,257) hit=False
#   centroid (0, 2): display=(475,222) hit=False
#   centroid (0, 3): display=(520,186) hit=False
#   centroid (0, 4): display=(576,222) hit=False
#   centroid (0, 5): display=(519,234) hit=False
# [picker] box-select (crossing) 357 candidates, added 1 entities
# [picker] closed — 0 physical group(s) written, 1 picks in working set
# [Mesh] set_global_size(max=0.5, min=0.0)
# [Mesh] generate(dim=3)
# [MeshViewer] closed — 0 nodes picked, 0 elements picked, 0 BRep patches selected
# [Mesh] get_nodes → 680 nodes
# [Mesh] get_elements → 1320 elements (1 types)
# [Mesh] renumber_mesh(method='rcm'): 680 nodes, 1320 elements, bandwidth=40
# [Mesh] get_nodes → 680 nodes
# [Mesh] get_elements → 1320 elements (1 types)
# [Mesh] get_fem_data(dim=2) → FEMData: 680 nodes, 1320 elements, bandwidth=598
